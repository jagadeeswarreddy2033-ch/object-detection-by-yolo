# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadeeswarreddy2033-ch/object-detection-by-yolo/blob/main/object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
import ultralytics
ultralytics.checks()
from ultralytics import YOLO

# Load a model
model = YOLO("v4.pt")  # pretrained YOLO26n model

# Run batched inference on a list of images
results = model(["CottonPlant.JPG"])

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs

    result.show()  # display to screen
    result.save(filename="result.jpg")  # save to disk
# Out:
# Ultralytics 8.4.89 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 20.0/107.7 GB disk)
#
# 0: 480x640 2 G-barbadenses, 292.8ms
# Speed: 27.6ms preprocess, 292.8ms inference, 34.0ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=1280x914>
